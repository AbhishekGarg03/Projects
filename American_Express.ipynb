# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('train_allx.csv')

# %%
df= df.sort_index(axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458913 entries, 0 to 458912
# Columns: 189 entries, B_1 to S_9
# dtypes: float64(184), int64(3), object(2)
# memory usage: 661.7+ MB

# %%
df.head(10)
# Out:
#         B_1      B_10      B_11  B_12  B_13      B_14      B_15      B_17  \
# 0  0.032715  0.002903  0.028824   0.0   2.0  0.000500  0.004124  0.001782
# 1  0.136108  0.030136  0.063904   0.0   3.0  1.000000  0.005260  0.002260
# 2  0.040619  0.000469  0.005989   0.0   2.0  1.008789  0.001832  0.005291
# 3  0.010315  0.006641 -0.001622   0.0   2.0  0.007515  0.006512  0.006260
# 4  0.135376  0.007542  0.011070   0.0   2.0  0.005013  0.007729  0.006237
# 5  0.450684  0.002855  0.018997   0.0   3.0  0.008850  0.003723  0.002071
# 6  0.008499  0.006989 -0.030548   0.0   1.0  0.005375  0.006680  0.004105
# 7  0.036621  0.021164  0.059906   0.0   2.0  0.007675  0.001070  0.004333
# 8  0.011292  0.001072  0.147827   0.0   1.0  0.008354  0.005764  0.008911
# 9  0.070679  0.421143  0.326904   1.0   3.0  1.007812  1.005859  0.419434
#
#        B_18      B_19  ...      S_23      S_24      S_25      S_26       S_3  \
# ...

# %%
df.columns
# Out:
# Index(['B_1', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_17', 'B_18',
#        'B_19',
#        ...
#        'S_23', 'S_24', 'S_25', 'S_26', 'S_3', 'S_4', 'S_5', 'S_7', 'S_8',
#        'S_9'],
#       dtype='object', length=189)

# %%
df.isnull().sum().values
# Out:
# array([     0,     31,      0,     31,     31,   4091,      0,     31,
#            31,      0,      0,      0,   1563, 452771,      0,      0,
#             0, 431589,      0, 244471,     31,      0,     31,      0,
#            31,      0,      0,      0,      0,      0,      0,      0,
#            40,      0,     31,     31,    612, 454808,    612,     31,
#             0, 343295,   1240,     31,   6017, 407150, 244734,     31,
#          2830, 407265, 409597, 442518,      0, 442518,   6017,     31,
#             0,   2830,   6017,   1240,      0,      0, 442518, 213837,
#          2830,      0,   2830, 399003, 378598,      0, 458268,   2830,
#          9012,      0,   6017,  48348,   2830,      0,   6017,      0,
#             0, 245602,   6017,   6365,      0, 458086, 455235,  12807,
#         57992,      0, 456286,  10037,   6017, 406331,   6017,      0,
#          1701,   2830,      0,   6017,   2830,  22295,   1190,  22295,
# ...

# %%
n = len(df)
m= df['B_1'].isnull().sum()
a = m/n
print ("%f" %a)
# Out:
# 0.000000

# %%
df_= df.copy()
for col in df.columns:
     if df[col].isnull().mean()>0.8:
        df_=df_.drop(col,axis=1)

# %%
df_.shape
df_.columns
# Out:
# Index(['B_1', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_17', 'B_18',
#        'B_19',
#        ...
#        'S_23', 'S_24', 'S_25', 'S_26', 'S_3', 'S_4', 'S_5', 'S_7', 'S_8',
#        'S_9'],
#       dtype='object', length=166)

# %%
n=df_.D_36.value_counts()
m=df_.D_44.value_counts()
print(n,m)
# Out:
# CO    344890
# CR     73178
# CL     35271
# XZ      3263
# XM      1503
# XL       808
# Name: D_36, dtype: int64 O    244622
# U    132722
# R     71532
# Name: D_44, dtype: int64

# %%
m = df.dtypes.values=='object'
for i in range(len(m)):
    if m[i]==True:
        print(df.columns[i])
# Out:
# D_36
# D_44

# %%
df_ = pd.get_dummies(df_, columns = ['D_44', 'D_36'])

# %%
df_.isnull().sum().values
# Out:
# array([     0,     31,      0,     31,     31,   4091,      0,     31,
#            31,      0,      0,      0,   1563,      0,      0,      0,
#             0, 244471,     31,      0,     31,      0,     31,      0,
#             0,      0,      0,      0,      0,      0,     40,      0,
#            31,     31,    612,    612,     31,      0, 343295,   1240,
#            31,   6017, 244734,     31,   2830,      0,   6017,     31,
#             0,   2830,   6017,   1240,      0,      0, 213837,   2830,
#             0,   2830,      0,   2830,   9012,      0,   6017,  48348,
#          2830,      0,   6017,      0,      0, 245602,   6017,   6365,
#         12807,  57992,      0,   6017,   6017,      0,   1701,   2830,
#             0,   6017,   2830,  22295,   1190,  22295,      0,      0,
#         58953,   4196,   2795, 325932,   1701,   2830,   6017,   1240,
#             0,     31,  95123,   6017,   2830,      0,      0,   2830,
# ...

# %%
print(df_.columns)
df_.shape
# Out:
# Index(['B_1', 'B_10', 'B_11', 'B_12', 'B_13', 'B_14', 'B_15', 'B_17', 'B_18',
#        'B_19',
#        ...
#        'S_9', 'D_44_O', 'D_44_R', 'D_44_U', 'D_36_CL', 'D_36_CO', 'D_36_CR',
#        'D_36_XL', 'D_36_XM', 'D_36_XZ'],
#       dtype='object', length=173)
# (458913, 173)

# %%
for col in df_.columns:
    #print(df_[col])
     df_[col].fillna(value= df_[col].mean())

# %%
df_.head()
# Out:
#         B_1      B_10      B_11  B_12  B_13      B_14      B_15      B_17  \
# 0  0.032715  0.002903  0.028824   0.0   2.0  0.000500  0.004124  0.001782
# 1  0.136108  0.030136  0.063904   0.0   3.0  1.000000  0.005260  0.002260
# 2  0.040619  0.000469  0.005989   0.0   2.0  1.008789  0.001832  0.005291
# 3  0.010315  0.006641 -0.001622   0.0   2.0  0.007515  0.006512  0.006260
# 4  0.135376  0.007542  0.011070   0.0   2.0  0.005013  0.007729  0.006237
#
#        B_18      B_19  ...       S_9  D_44_O  D_44_R  D_44_U  D_36_CL  \
# 0  0.002880  0.013100  ...  0.165771       1       0       0        0
# 1  0.838867  0.468994  ...  0.706543       1       0       0        1
# 2  0.006405  0.028595  ...  0.160034       1       0       0        0
# 3  0.092346  0.188110  ...  0.194092       1       0       0        0
# 4  0.172974  0.009392  ...  0.164185       1       0       0        0
#
#    D_36_CO  D_36_CR  D_36_XL  D_36_XM  D_36_XZ
# 0        1        0        0        0        0
# ...

# %%
n = len(df_)

n_val = int(n*0.2)
n_test =int(n*0.2)
n_train = n-n_val-n_test

# %%
idx =np.arange(n)
np.random.seed(2)
np.random.shuffle(idx)

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:]]
